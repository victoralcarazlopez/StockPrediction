# %%
# LIBRERIAS

import os
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
import math
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping
import keras_tuner as kt



#Comprobar que Tensorflow reconoce la tarjeta gráfica del equipo
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Lectura de ficheros con los datasets de las empresas a analizar
companies = {}
ficheros = os.listdir('data')

for file in ficheros:
    company = file[:-4]
    dfcompany = pd.read_csv(f"data/{file}")
    companies[company] = dfcompany

# %%
# Comprobación que de todas las empresas se dispone de al menos 1000 días de datos
for company in companies:
    dfcompany = companies[company]
    if dfcompany.shape[0] < 1000:
        print(company)

# %%
# Crreación de una matriz de datos de para la red neuronal
def create_dataset(dataset, look_back):
	x_data, y_data = [], []
	for i in range(len(dataset)-look_back-1):
		x = dataset[i:(i+look_back), 0]
		x_data.append(x)
		y = dataset[i + look_back, 0]
		y_data.append(y)
        
	return np.array(x_data), np.array(y_data)

def graficar(dfcompany, company):
	plt.plot(dfcompany)
	plt.xlabel('Days')
	plt.ylabel('Price')
	plt.title(label=company)

# Graficar el resultado
def graficarResultado(dfcompany, scaler, look_back, train_predict, test_predict):
    # Ajustamos los datos para mostrar la predicción
    trainPredictPlot = np.empty_like(dfcompany)
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[look_back:len(train_predict)+look_back,:] = train_predict
    
    testPredictPlot = np.empty_like(dfcompany)
    testPredictPlot[:, :] = np.nan
    testPredictPlot[len(train_predict)+(look_back*2)+1:len(dfcompany)-1, :] = test_predict

    # Mostrar las los datos originales y la predicción
    plt.plot(scaler.inverse_transform(dfcompany), label='Original data')
    plt.plot(trainPredictPlot, label='Train prediction')
    plt.plot(testPredictPlot, label='Test prediction')
    plt.legend()
    
    plt.xlabel('Days')
    plt.ylabel('Price')
    plt.show()
	
#Separar datos de entrenamiento y test
def split(dfcompany, look_back, percent=70):
    training_size = int(len(dfcompany)*percent) 
    test_size = len(dfcompany)-training_size 

    train_data, test_data = dfcompany[0:training_size,:], dfcompany[training_size:len(dfcompany),:1]


    #Creamos la matrix para los datos de entrenamiento y test    
    X_train, y_train = create_dataset(train_data, look_back) 
    X_test, y_test = create_dataset(test_data, look_back) 
    #print(f"La matriz X_train tiene la forma: {X_train.shape}")
    #print(f"La matriz y_train tiene la forma: {y_train.shape}")
    #print(f"La matriz X_test tiene la forma: {X_test.shape}")
    #print(f"La matriz y_test tiene la forma: {y_test.shape}")
    

    # Hay que hacer reshape a las entradas de la red LSTM añadiendo 1 dimension [samples, look_back, features]
    X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
    X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)


    return X_train, X_test, y_train, y_test

# %%
def model_builder(hp):
  '''
  Args:
    hp - Keras tuner object
  '''
  # Initialize the Sequential API and start stacking the layers
  model = keras.Sequential()

  # Tune the number of units in the first LSTM layer
  # Choose an optimal value between 10-100
  hp_units0 = hp.Int('units0', min_value=10, max_value=100, step=20)
  model.add(LSTM(units=hp_units0, input_shape=(look_back,1), return_sequences=True, name='LSTM1'))

  # Tune the number of units in the second LSTM layer
  # Choose an optimal value between 10-100
  hp_units1 = hp.Int('units1', min_value=10, max_value=100, step=20)
  model.add(LSTM(units=hp_units1, name='LSTM2'))
  
  # Add next layers
  model.add(keras.layers.Dropout(0.2))
  model.add(Dense(1, activation='linear'))

  # Tune the learning rate for the optimizer
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='mean_squared_error',
                metrics=['mse'])

  return model

# %%
def prediccion (model, X_train, X_test, y_train, y_test, look_back, scaler):
    # Realizar predicción sobre datos de entranamiento y test
    train_predict = model.predict(X_train)
    test_predict = model.predict(X_test)

    # Transformamos los datos a su escala original
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)

    return  train_predict, test_predict

def generarHipermodelo(X_train, y_train, X_test, y_test): 


    # Perform hypertuning
    tuner.search(X_train, y_train, epochs=10, validation_data=(X_test,y_test), callbacks=[stop_early]) 

    best_hp = tuner.get_best_hyperparameters()[0]

    # Build the model with the optimal hyperparameters
    h_model = tuner.hypermodel.build(best_hp)
    h_model.summary()
    print(tuner.get_best_hyperparameters()[0].get('learning_rate'))

    return h_model

def generarResultados(dfcompany):
    #dfcompany = companies[company]
    # Por cada empresa, preprocesar, entrenar y guardar resultados
    company = dfcompany.iloc[0,0]

    # Descartamos todas las columnas y nos quedamos unicamente con el precio de cierre de la acción
    dfcompany = dfcompany.reset_index()['close']
    scaler = MinMaxScaler(feature_range=(0,1))
    dfcompany = scaler.fit_transform(np.array(dfcompany).reshape(-1,1))
    X_train, X_test, y_train, y_test = split(dfcompany, look_back, percent=0.90)

    h_model = generarHipermodelo(X_train, y_train, X_test, y_test)
    #Entrenamiento del modelo mejorado
    history = h_model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.2, callbacks=[stop_early])

    train_predict, test_predict = prediccion(h_model, X_train, X_test, y_train, y_test, look_back, scaler)

    # Calculamos el error en entrenamiento y test
    train_error = math.sqrt(mean_squared_error(y_train, train_predict))
    test_error = math.sqrt(mean_squared_error(y_test, test_predict))

    print(f"Para la empresa {company}")
    print(f"Error entrenamiento: {train_error}")
    print(f"Error test: {test_error}")

    #graficarResultado(dfcompany, scaler, look_back, train_predict, test_predict)
    return (train_error, test_error)

# %%
# Definimos cuantos días usará el modelo para predecir el día siguiente
look_back = 50

# Instanciamos el tuner
tuner = kt.Hyperband(model_builder, # the hypermodel
                    objective='val_loss', # objective to optimize
                    max_epochs=10,
                    factor=3, # the denominator of the number of models trained in every iteration of the training loop.
                    directory='keras_tuner_dir', # directory to save logs 
                    project_name='Stock_prediction')

# hypertuning settings
tuner.search_space_summary() 

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss',mode='min', patience=10, min_delta=0.2)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project keras_tuner_dir\Stock_prediction\oracle.json
# INFO:tensorflow:Reloading Tuner from keras_tuner_dir\Stock_prediction\tuner0.json
# Search space summary
# Default search space size: 3
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 100, 'step': 20, 'sampling': None}
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 100, 'step': 20, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
dictErrores = {}
for company in companies:
    #if company == 'AMZN':
    print("\n\n\n")
    print(f"Entrenando para {company}...")
    dfcompany = companies[company]
    dictErrores[company] = generarResultados(dfcompany)
# Out:
# Entrenando para AAL...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 12s 115ms/step - loss: 0.1085 - mse: 0.1085 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 2/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 8.6540e-04 - val_mse: 8.6540e-04
# Epoch 3/50
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 4/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 4.6634e-04 - val_mse: 4.6634e-04
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 4.0882e-04 - val_mse: 4.0882e-04
# Epoch 6/50
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 5.3061e-04 - val_mse: 5.3061e-04
# Epoch 7/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 4.1869e-04 - val_mse: 4.1869e-04
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 4.0214e-04 - val_mse: 4.0214e-04
# Epoch 9/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 6.8011e-04 - val_mse: 6.8011e-04
# Epoch 10/50
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 4.0361e-04 - val_mse: 4.0361e-04
# Epoch 11/50
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 4.1888e-04 - val_mse: 4.1888e-04
# Para la empresa AAL
# Error entrenamiento: 31.986895876670655
# Error test: 17.112231552858635
#
#
#
#
# Entrenando para AAPL...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 6s 78ms/step - loss: 0.0243 - mse: 0.0243 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 2/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 4.8547e-04 - val_mse: 4.8547e-04
# Epoch 3/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 5.6674e-04 - val_mse: 5.6674e-04
# Epoch 4/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 9.3718e-05 - val_mse: 9.3718e-05
# Epoch 5/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 6/50
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 4.8364e-05 - val_mse: 4.8364e-05
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 4.6478e-05 - val_mse: 4.6478e-05
# Epoch 9/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 1.5840e-04 - val_mse: 1.5840e-04
# Epoch 10/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 9.1775e-04 - val_mse: 9.1775e-04
# Epoch 11/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 6.6955e-04 - val_mse: 6.6955e-04
# Para la empresa AAPL
# Error entrenamiento: 217.55420603051678
# Error test: 173.71733273485268
#
#
#
#
# Entrenando para ADBE...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 5s 84ms/step - loss: 0.0481 - mse: 0.0481 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 2/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 3/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 4/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 5/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 6/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 9/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 10/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 11/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0033 - val_mse: 0.0033
# Para la empresa ADBE
# Error entrenamiento: 362.12634433392094
# Error test: 430.12670731828473
#
#
#
#
# Entrenando para ADI...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 75ms/step - loss: 0.0285 - mse: 0.0285 - val_loss: 0.0299 - val_mse: 0.0299
# Epoch 2/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 3/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 6/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 7/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 9/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 10/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 11/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0057 - val_mse: 0.0057
# Para la empresa ADI
# Error entrenamiento: 121.54032627656188
# Error test: 164.8940050484704
#
#
#
#
# Entrenando para ADP...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 79ms/step - loss: 0.0440 - mse: 0.0440 - val_loss: 0.0676 - val_mse: 0.0676
# Epoch 2/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 3/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 4/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 6.5979e-04 - val_mse: 6.5979e-04
# Epoch 5/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 9.4877e-04 - val_mse: 9.4877e-04
# Epoch 6/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 7/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 9.7546e-04 - val_mse: 9.7546e-04
# Epoch 8/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 9/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 10/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 11/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0049 - val_mse: 0.0049
# Para la empresa ADP
# Error entrenamiento: 152.22154278734675
# Error test: 203.45308013621548
#
#
#
#
# Entrenando para ADSK...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 74ms/step - loss: 0.0358 - mse: 0.0358 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0282 - val_mse: 0.0282
# Epoch 3/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 4/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 5/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 9/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 10/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0016 - val_mse: 0.0016
# Para la empresa ADSK
# Error entrenamiento: 200.36757654717726
# Error test: 204.3070353457006
#
#
#
#
# Entrenando para AKAM...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 74ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0920 - val_mse: 0.0920
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 3/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 6/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 7/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 9/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 10/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0015 - val_mse: 0.0015
# Para la empresa AKAM
# Error entrenamiento: 87.81514978767088
# Error test: 109.36767417175184
#
#
#
#
# Entrenando para ALXN...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 12/12 [==============================] - 4s 97ms/step - loss: 0.0361 - mse: 0.0361 - val_loss: 0.0125 - val_mse: 0.0125
# Epoch 2/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 3/50
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 4/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 5/50
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 6/50
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 7/50
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 8/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 9/50
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 10/50
# 12/12 [==============================] - 0s 26ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 11/50
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0032 - val_mse: 0.0032
# Para la empresa ALXN
# Error entrenamiento: 117.44982008201941
# Error test: 167.90884098045626
#
#
#
#
# Entrenando para AMAT...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 74ms/step - loss: 0.0197 - mse: 0.0197 - val_loss: 0.2209 - val_mse: 0.2209
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0615 - val_mse: 0.0615
# Epoch 3/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 8.0500e-04 - mse: 8.0500e-04 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 5/50
# 14/14 [==============================] - 0s 15ms/step - loss: 6.2495e-04 - mse: 6.2495e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 6/50
# 14/14 [==============================] - 0s 15ms/step - loss: 6.8033e-04 - mse: 6.8033e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 4.9905e-04 - mse: 4.9905e-04 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 8/50
# 14/14 [==============================] - 0s 17ms/step - loss: 5.3793e-04 - mse: 5.3793e-04 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 9/50
# 14/14 [==============================] - 0s 22ms/step - loss: 5.1567e-04 - mse: 5.1567e-04 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 10/50
# 14/14 [==============================] - 0s 18ms/step - loss: 4.7673e-04 - mse: 4.7673e-04 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 4.6208e-04 - mse: 4.6208e-04 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 12/50
# 14/14 [==============================] - 0s 16ms/step - loss: 4.7003e-04 - mse: 4.7003e-04 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 13/50
# 14/14 [==============================] - 0s 19ms/step - loss: 4.6867e-04 - mse: 4.6867e-04 - val_loss: 0.0051 - val_mse: 0.0051
# Para la empresa AMAT
# Error entrenamiento: 77.78605838807883
# Error test: 131.46767989698716
#
#
#
#
# Entrenando para AMGN...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 79ms/step - loss: 0.0810 - mse: 0.0810 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 3/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 4/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 8/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 9/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 10/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0021 - val_mse: 0.0021
# Para la empresa AMGN
# Error entrenamiento: 210.6008217202712
# Error test: 238.28452561743333
#
#
#
#
# Entrenando para AMZN...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 85ms/step - loss: 0.0383 - mse: 0.0383 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 3/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 4/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 9.8528e-04 - val_mse: 9.8528e-04
# Epoch 5/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 9.2806e-04 - val_mse: 9.2806e-04
# Epoch 9/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 10/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 11/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0020 - val_mse: 0.0020
# Para la empresa AMZN
# Error entrenamiento: 2318.5072753271493
# Error test: 2871.3693253831552
#
#
#
#
# Entrenando para ATVI...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 69ms/step - loss: 0.0501 - mse: 0.0501 - val_loss: 0.0263 - val_mse: 0.0263
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 3/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 4/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 5/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 6/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 7/50
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 9/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 10/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0020 - val_mse: 0.0020
# Para la empresa ATVI
# Error entrenamiento: 69.65319369000632
# Error test: 78.31054705719026
#
#
#
#
# Entrenando para AVGO...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 85ms/step - loss: 0.0191 - mse: 0.0191 - val_loss: 0.1044 - val_mse: 0.1044
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 3/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 4/50
# 14/14 [==============================] - 0s 17ms/step - loss: 9.9707e-04 - mse: 9.9707e-04 - val_loss: 5.9613e-04 - val_mse: 5.9613e-04
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 8.6445e-04 - mse: 8.6445e-04 - val_loss: 7.0069e-04 - val_mse: 7.0069e-04
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 8.5951e-04 - mse: 8.5951e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 7.7349e-04 - mse: 7.7349e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 8.1335e-04 - mse: 8.1335e-04 - val_loss: 6.9388e-04 - val_mse: 6.9388e-04
# Epoch 9/50
# 14/14 [==============================] - 0s 15ms/step - loss: 6.5029e-04 - mse: 6.5029e-04 - val_loss: 4.9295e-04 - val_mse: 4.9295e-04
# Epoch 10/50
# 14/14 [==============================] - 0s 17ms/step - loss: 6.6484e-04 - mse: 6.6484e-04 - val_loss: 6.9506e-04 - val_mse: 6.9506e-04
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 5.8086e-04 - mse: 5.8086e-04 - val_loss: 5.2878e-04 - val_mse: 5.2878e-04
# Para la empresa AVGO
# Error entrenamiento: 332.4756415379994
# Error test: 614.3274659968503
#
#
#
#
# Entrenando para BBBY...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 73ms/step - loss: 0.0363 - mse: 0.0363 - val_loss: 0.0323 - val_mse: 0.0323
# Epoch 2/50
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 3/50
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 4/50
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 5/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 6/50
# 14/14 [==============================] - 0s 26ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 7/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 8/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 9/50
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 10/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 11/50
# 14/14 [==============================] - 0s 17ms/step - loss: 9.9918e-04 - mse: 9.9918e-04 - val_loss: 0.0040 - val_mse: 0.0040
# Para la empresa BBBY
# Error entrenamiento: 19.129598002691694
# Error test: 17.86404704923165
#
#
#
#
# Entrenando para BIDU...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 5s 81ms/step - loss: 0.1788 - mse: 0.1788 - val_loss: 0.0311 - val_mse: 0.0311
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 3/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 9/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 10/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0030 - val_mse: 0.0030
# Para la empresa BIDU
# Error entrenamiento: 181.53397949020976
# Error test: 136.8116980587504
#
#
#
#
# Entrenando para BIIB...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 83ms/step - loss: 0.0557 - mse: 0.0557 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 2/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0096 - val_mse: 0.0096
# Epoch 3/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 6/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 7/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 8/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 9/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 10/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0038 - val_mse: 0.0038
# Para la empresa BIIB
# Error entrenamiento: 291.9154947465443
# Error test: 209.9152267317921
#
#
#
#
# Entrenando para BMRN...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 72ms/step - loss: 0.0529 - mse: 0.0529 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 3/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 4/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 5/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 9/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 10/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0011 - val_mse: 0.0011
# Para la empresa BMRN
# Error entrenamiento: 87.54738779045249
# Error test: 82.03921456147728
#
#
#
#
# Entrenando para CERN...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 91ms/step - loss: 0.0297 - mse: 0.0297 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 2/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 3/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 8.3311e-04 - val_mse: 8.3311e-04
# Epoch 6/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 7/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 8.1468e-04 - val_mse: 8.1468e-04
# Epoch 8/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 9/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 10/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 11/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 6.7746e-04 - val_mse: 6.7746e-04
# Para la empresa CERN
# Error entrenamiento: 68.51375804068878
# Error test: 88.74550067557006
#
#
#
#
# Entrenando para CHKP...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 80ms/step - loss: 0.0465 - mse: 0.0465 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 3/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 9/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 10/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 11/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0012 - val_mse: 0.0012
# Para la empresa CHKP
# Error entrenamiento: 113.55338685926702
# Error test: 133.1714753740786
#
#
#
#
# Entrenando para CHTR...
# ...
# Epoch 7/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 3.3807e-04 - val_mse: 3.3807e-04
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 3.6069e-04 - val_mse: 3.6069e-04
# Epoch 9/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 4.1708e-04 - val_mse: 4.1708e-04
# Epoch 10/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 3.3547e-04 - val_mse: 3.3547e-04
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 3.1834e-04 - val_mse: 3.1834e-04
# Para la empresa VOD
# Error entrenamiento: 20.520348577364896
# Error test: 16.576483140507108
#
#
#
#
# Entrenando para VRSK...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_84"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_84 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_84 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 82ms/step - loss: 0.0590 - mse: 0.0590 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 2/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 3/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 5/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 6/50
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 9.9529e-04 - val_mse: 9.9529e-04
# Epoch 7/50
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 8/50
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 9.0034e-04 - val_mse: 9.0034e-04
# Epoch 9/50
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 9.2241e-04 - val_mse: 9.2241e-04
# Epoch 10/50
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 11/50
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0019 - val_mse: 0.0019
# Para la empresa VRSK
# Error entrenamiento: 147.77785615958535
# Error test: 191.9258231628449
#
#
#
#
# Entrenando para VRTX...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_85"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_85 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_85 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 89ms/step - loss: 0.1165 - mse: 0.1165 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 3/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 8.4577e-04 - val_mse: 8.4577e-04
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 7.7701e-04 - val_mse: 7.7701e-04
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 7/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 7.0629e-04 - val_mse: 7.0629e-04
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 7.5168e-04 - val_mse: 7.5168e-04
# Epoch 9/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 10/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 8.9411e-04 - val_mse: 8.9411e-04
# Epoch 11/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 6.9285e-04 - val_mse: 6.9285e-04
# Para la empresa VRTX
# Error entrenamiento: 200.16231771332673
# Error test: 251.4313265134009
#
#
#
#
# Entrenando para WBA...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_86"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_86 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 74ms/step - loss: 0.0784 - mse: 0.0784 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 2/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 3/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 4/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 6/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 7.0064e-04 - val_mse: 7.0064e-04
# Epoch 7/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 7.9591e-04 - val_mse: 7.9591e-04
# Epoch 8/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 7.3692e-04 - val_mse: 7.3692e-04
# Epoch 9/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 7.2111e-04 - val_mse: 7.2111e-04
# Epoch 10/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 6.4241e-04 - val_mse: 6.4241e-04
# Epoch 11/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 7.2133e-04 - val_mse: 7.2133e-04
# Para la empresa WBA
# Error entrenamiento: 58.405345123618126
# Error test: 46.10647679749855
#
#
#
#
# Entrenando para WDC...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_87"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_87 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_87 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 81ms/step - loss: 0.0351 - mse: 0.0351 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 3/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 4/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 9.1700e-04 - val_mse: 9.1700e-04
# Epoch 5/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 6/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 7/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 8/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 9/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 10/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 11/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 7.8719e-04 - val_mse: 7.8719e-04
# Para la empresa WDC
# Error entrenamiento: 62.61171509243283
# Error test: 52.10809013655106
#
#
#
#
# Entrenando para XLNX...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_88"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_88 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_88 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 13/13 [==============================] - 4s 92ms/step - loss: 0.0660 - mse: 0.0660 - val_loss: 0.0457 - val_mse: 0.0457
# Epoch 2/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 3/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 4/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 5/50
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 6/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 7/50
# 13/13 [==============================] - 0s 16ms/step - loss: 9.7790e-04 - mse: 9.7790e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 8/50
# 13/13 [==============================] - 0s 17ms/step - loss: 9.5081e-04 - mse: 9.5081e-04 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 9/50
# 13/13 [==============================] - 0s 15ms/step - loss: 9.0851e-04 - mse: 9.0851e-04 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 10/50
# 13/13 [==============================] - 0s 17ms/step - loss: 8.5684e-04 - mse: 8.5684e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 11/50
# 13/13 [==============================] - 0s 16ms/step - loss: 8.3400e-04 - mse: 8.3400e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Para la empresa XLNX
# Error entrenamiento: 100.47777775312326
# Error test: 195.28372851201138
#
#
#
#
# Entrenando para XRAY...
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_89"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_89 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_89 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/50
# 14/14 [==============================] - 4s 81ms/step - loss: 0.0665 - mse: 0.0665 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 2/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 3/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 4/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 5/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 6/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 7/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 8/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 9/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 10/50
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 11/50
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0016 - val_mse: 0.0016
# Para la empresa XRAY
# Error entrenamiento: 52.32173721486323
# Error test: 47.761928961816004

# %%
for company in dictErrores:
    print (company+ " " + str(dictErrores[company]))
# Out:
# AAL (31.986895876670655, 17.112231552858635)
# AAPL (217.55420603051678, 173.71733273485268)
# ADBE (362.12634433392094, 430.12670731828473)
# ADI (121.54032627656188, 164.8940050484704)
# ADP (152.22154278734675, 203.45308013621548)
# ADSK (200.36757654717726, 204.3070353457006)
# AKAM (87.81514978767088, 109.36767417175184)
# ALXN (117.44982008201941, 167.90884098045626)
# AMAT (77.78605838807883, 131.46767989698716)
# AMGN (210.6008217202712, 238.28452561743333)
# AMZN (2318.5072753271493, 2871.3693253831552)
# ATVI (69.65319369000632, 78.31054705719026)
# AVGO (332.4756415379994, 614.3274659968503)
# BBBY (19.129598002691694, 17.86404704923165)
# BIDU (181.53397949020976, 136.8116980587504)
# BIIB (291.9154947465443, 209.9152267317921)
# BMRN (87.54738779045249, 82.03921456147728)
# CERN (68.51375804068878, 88.74550067557006)
# CHKP (113.55338685926702, 133.1714753740786)
# CHTR (507.10561621502933, 561.9437559338056)
# CMCSA (43.412134778990016, 45.076490490375676)
# COST (305.1411240373245, 542.210039290334)
# CSCO (46.727861011486674, 53.16924813254538)
# CSX (68.7776723672446, 36.751847079293526)
# CTRP (36.00402582621651, 23.89770787954847)
# CTSH (70.20314355547681, 84.1137351847396)
# CTXS (110.75570528802189, 100.7761089664198)
# DISCK (26.900521696403924, 27.40280920142287)
# DISH (36.150020519934515, 29.44834815328581)
# DLTR (97.11581031727431, 150.23411762070856)
# EA (116.8863826773663, 123.18769885473938)
# EBAY (46.591671006249946, 54.147082213834025)
# EXPE (121.1361734288399, 165.00264377842572)
# FAST (49.89285414269368, 56.06089355145378)
# FB (221.2292616137432, 203.42293319595709)
# FISV (102.98950431991878, 97.7702550452627)
# GILD (69.44508817555823, 61.44615139949859)
# GOOGL (1563.9554946003886, 2544.858934851437)
# HSIC (71.73080413313029, 81.9322481004253)
# ILMN (331.9931177390336, 325.31724049764773)
# INCY (82.99560226626444, 74.0894203020941)
# INTC (50.64054707040247, 46.07848009610833)
# INTU (306.79359141545007, 464.77853674380646)
# ISRG (585.0615565345803, 279.15325557678887)
# JD (53.12757941327467, 61.059115229802664)
# LBTYA (26.015810081880407, 24.59366273183918)
# LBTYK (25.379041824676168, 25.086198815621554)
# LRCX (364.15684613528657, 547.703855184649)
# MAR (123.73560691118763, 162.47027055601902)
# MAT (14.190646091860097, 21.336354448465613)
# MCHP (107.4324354381226, 72.9018391920153)
# MDLZ (51.207744702881264, 62.373879678223524)
# MNST (68.98611234571841, 80.27693617485764)
# MSFT (171.1174135585769, 275.1544050186964)
# MU (56.34188633898129, 79.66429188855783)
# MXIM (60.88946605851869, 93.30098802110068)
# NCLH (44.89997163572346, 20.692286038943593)
# NFLX (411.38425252762744, 339.78254427224357)
# NTAP (65.37887308329044, 81.19619475213794)
# NTES (268.6825693751693, 96.70315054684656)
# NVDA (335.7332857824374, 227.70898428615817)
# NXPI (135.36605284017693, 188.86368787899846)
# ORLY (415.13916967739726, 665.223991156005)
# PAYX (79.15129956188083, 119.82167435420807)
# PCAR (75.23309232739932, 86.85967172223516)
# PYPL (159.6078143302668, 107.92694281538533)
# QCOM (92.42315958716279, 146.58122736112844)
# REGN (449.0572671145609, 642.9922313496864)
# ROST (94.42820980203356, 90.82595428631772)
# SBAC (237.1469274236647, 317.3134126095806)
# SBUX (82.37057804925067, 83.9487396980615)
# SIRI (5.61910454481665, 5.703670404916165)
# SRCL (60.12928560041526, 54.48014192741599)
# STX (58.47590582493887, 89.77999885505092)
# SWKS (122.38050842695056, 125.98148355764239)
# SYMC (22.935175176135516, 25.739111874693446)
# TMUS (93.0557216887601, 125.45140315947796)
# TRIP (40.22055261871244, 25.6969737588805)
# TSCO (119.036445295976, 209.6122515496151)
# TSLA (560.1214171053272, 852.9216013914606)
# TXN (132.95030865385476, 172.68219419532682)
# ULTA (269.3617090626596, 371.49760920765584)
# VOD (20.520348577364896, 16.576483140507108)
# VRSK (147.77785615958535, 191.9258231628449)
# VRTX (200.16231771332673, 251.4313265134009)
# WBA (58.405345123618126, 46.10647679749855)
# WDC (62.61171509243283, 52.10809013655106)
# XLNX (100.47777775312326, 195.28372851201138)
# XRAY (52.32173721486323, 47.761928961816004)

# %%
errors = pd.DataFrame(list(dictErrores.values()))
#print(errors)
train_errors = errors[0]
test_errors = errors[1]


print (f"La media del RMSE obtenido en entrenamiento entrenando cada empresa por separado es {np.mean(train_errors)}")
print (f"La media del RMSE obtenido en test entrenando cada empresa por separado es {np.mean(test_errors)}")
# Out:
# La media del RMSE obtenido en entrenamiento entrenando cada empresa por separado es 183.45011332251832
# La media del RMSE obtenido en test entrenando cada empresa por separado es 223.46703801129905

# %%
df_train_errors = pd.DataFrame(train_errors)
df_test_errors = pd.DataFrame(test_errors)

#df_train_errors.describe()
df_test_errors.describe()
# Out:
#                  1
# count    89.000000
# mean    223.467038
# std     415.389260
# min       5.703670
# 25%      56.060894
# 50%     107.926943
# 75%     204.307035
# max    2871.369325
