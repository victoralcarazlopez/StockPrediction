# %%
# LIBRERIAS

import os
import tensorflow as tf
import tensorflow.keras as keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.model_selection import TimeSeriesSplit
import math
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import GridSearchCV
import kerastuner as kt



tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Lectura de ficheros con los datasets de las empresas a analizar

companies = {}
ficheros = os.listdir('data')

for file in ficheros:
    company = file[:-4]
    dfcompany = pd.read_csv(f"data/{file}")
    companies[company] = dfcompany

# %%
# Tomamos datos de amazon para pruebas con el modelo.
dfcompany = companies['MSFT']
dfcompany
# Out:
#      symbol                       date   close    high     low     open  \
# 0      MSFT  2017-05-22 00:00:00+00:00   68.45   68.50   67.50   67.890
# 1      MSFT  2017-05-23 00:00:00+00:00   68.68   68.75   68.38   68.720
# 2      MSFT  2017-05-24 00:00:00+00:00   68.77   68.88   68.45   68.870
# 3      MSFT  2017-05-25 00:00:00+00:00   69.62   69.88   68.91   68.970
# 4      MSFT  2017-05-26 00:00:00+00:00   69.96   70.22   69.52   69.800
# ...     ...                        ...     ...     ...     ...      ...
# 1254   MSFT  2022-05-13 00:00:00+00:00  261.12  263.04  255.35  257.350
# 1255   MSFT  2022-05-16 00:00:00+00:00  261.50  265.82  255.78  259.955
# 1256   MSFT  2022-05-17 00:00:00+00:00  266.82  268.33  262.46  266.110
# 1257   MSFT  2022-05-18 00:00:00+00:00  254.08  263.60  252.77  263.000
# 1258   MSFT  2022-05-19 00:00:00+00:00  253.14  257.67  251.88  253.900
#
#         volume    adjClose     adjHigh      adjLow     adjOpen  adjVolume  \
# 0     15484530   64.097262   64.144083   63.207673   63.572873   15484530
# 1     15347877   64.312636   64.378185   64.031713   64.350093   15347877
# 2     14422965   64.396913   64.499918   64.097262   64.490554   14422965
# 3     21702912   65.192862   65.436328   64.528011   64.584195   21702912
# 4     19644260   65.511241   65.754708   65.099221   65.361416   19644260
# ...        ...         ...         ...         ...         ...        ...
# 1254  34925093  260.484372  262.399698  254.728418  256.723549   34925093
# 1255  32550933  260.863447  265.172931  255.157371  259.322208   32550933
# 1256  28828799  266.170497  267.676821  261.821110  265.462225   28828799
# 1257  31355985  254.080000  263.600000  252.770000  263.000000   31355985
# 1258  32692286  253.140000  257.670000  251.880000  253.900000   32692286
#
#       divCash  splitFactor
# 0        0.00          1.0
# 1        0.00          1.0
# 2        0.00          1.0
# 3        0.00          1.0
# 4        0.00          1.0
# ...       ...          ...
# 1254     0.00          1.0
# 1255     0.00          1.0
# 1256     0.00          1.0
# 1257     0.62          1.0
# 1258     0.00          1.0
#
# [1259 rows x 14 columns]

# %%
# Crreación de una matriz de datos de para la red neuronal
def create_dataset(dataset, look_back):
	x_data, y_data = [], []
	for i in range(len(dataset)-look_back-1):
		x = dataset[i:(i+look_back), 0]
		x_data.append(x)
		y = dataset[i + look_back, 0]
		y_data.append(y)
        
	return np.array(x_data), np.array(y_data)

def graficar(dfcompany, company):
	plt.plot(dfcompany)
	plt.xlabel('Days')
	plt.ylabel('Price')
	plt.title(label=company)

# Graficar el resultado
def graficarResultado(dfcompany, look_back, train_predict, test_predict):
    # Ajustamos los datos para mostrar la predicción
    trainPredictPlot = np.empty_like(dfcompany)
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[look_back:len(train_predict)+look_back,:] = train_predict
    
    testPredictPlot = np.empty_like(dfcompany)
    testPredictPlot[:, :] = np.nan
    testPredictPlot[len(train_predict)+(look_back*2)+1:len(dfcompany)-1, :] = test_predict

    # Mostrar las los datos originales y la predicción
    plt.plot(scaler.inverse_transform(dfcompany), label='Original data')
    plt.plot(trainPredictPlot, label='Train prediction')
    plt.plot(testPredictPlot, label='Test prediction')
    plt.legend()
    
    plt.xlabel('Days')
    plt.ylabel('Price')
    plt.show()
	
#Separar datos de entrenamiento y test
def split(dfcompany, look_back, percent=70):
    training_size = int(len(dfcompany)*percent) 
    test_size = len(dfcompany)-training_size 

    train_data, test_data = dfcompany[0:training_size,:], dfcompany[training_size:len(dfcompany),:1]


    #Creamos la matrix para los datos de entrenamiento y test    
    X_train, y_train = create_dataset(train_data, look_back) #(,) (,)
    X_test, y_test = create_dataset(test_data, look_back) #(,) (,)
    #print(f"La matriz X_train tiene la forma: {X_train.shape}")
    #print(f"La matriz y_train tiene la forma: {y_train.shape}")
    #print(f"La matriz X_test tiene la forma: {X_test.shape}")
    #print(f"La matriz y_test tiene la forma: {y_test.shape}")
    

    # Hay que hacer reshape a las entradas de la red LSTM añadiendo 1 dimension [samples, look_back, features]
    X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
    X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)


    return X_train, X_test, y_train, y_test

# %%
def model_builder(hp):
  '''
  Args:
    hp - Keras tuner object
  '''
  # Initialize the Sequential API and start stacking the layers
  model = keras.Sequential()

  # Tune the number of units in the first LSTM layer
  # Choose an optimal value between 10-100
  hp_units0 = hp.Int('units0', min_value=10, max_value=100, step=20)
  model.add(LSTM(units=hp_units0, input_shape=(look_back,1), return_sequences=True, name='LSTM1'))

  # Tune the number of units in the second LSTM layer
  # Choose an optimal value between 10-100
  hp_units1 = hp.Int('units1', min_value=10, max_value=100, step=20)
  model.add(LSTM(units=hp_units1, name='LSTM2'))
  
  # Add next layers
  model.add(keras.layers.Dropout(0.2))
  model.add(Dense(1, activation='linear'))

  # Tune the learning rate for the optimizer
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='mean_squared_error',
                metrics=['mse'])

  return model

# %%
def prediccion (model, X_train, X_test, y_train, y_test, look_back, scaler):
    # Realizar predicción sobre datos de entranamiento y test
    train_predict = model.predict(X_train)
    test_predict = model.predict(X_test)

    # Transformamos los datos a su escala original
    train_predict = scaler.inverse_transform(train_predict)
    test_predict = scaler.inverse_transform(test_predict)

    return  train_predict, test_predict

# %%
# Definimos cuantos días usará el modelo para predecir el día siguiente
look_back = 50

# Instanciamos el tuner
tuner = kt.Hyperband(model_builder, # the hypermodel
                    objective='val_loss', # objective to optimize
                    max_epochs=10,
                    factor=3, # the denominator of the number of models trained in every iteration of the training loop.
                    directory='keras_tuner_dir', # directory to save logs 
                    project_name='Stock_prediction')

# hypertuning settings
tuner.search_space_summary() 

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss',mode='min', patience=5, min_delta=0.2)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project keras_tuner_dir\Stock_prediction\oracle.json
# INFO:tensorflow:Reloading Tuner from keras_tuner_dir\Stock_prediction\tuner0.json
# Search space summary
# Default search space size: 3
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 100, 'step': 20, 'sampling': None}
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 100, 'step': 20, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
def generarHipermodelo(X_train, y_train, X_test, y_test): 


    # Perform hypertuning
    tuner.search(X_train, y_train, epochs=10, validation_data=(X_test,y_test), callbacks=[stop_early]) 

    best_hp = tuner.get_best_hyperparameters()[0]

    # Build the model with the optimal hyperparameters
    h_model = tuner.hypermodel.build(best_hp)
    h_model.summary()
    print(tuner.get_best_hyperparameters()[0].get('learning_rate'))

    return h_model

# %%
def generarResultados(dfcompany):
    #dfcompany = companies[company]
    # Por cada empresa, preprocesar, entrenar y guardar resultados
    company = dfcompany.iloc[0,0]

    # Descartamos todas las columnas y nos quedamos unicamente con el precio de cierre de la acción
    dfcompany = dfcompany.reset_index()['close']
    scaler=MinMaxScaler(feature_range=(0,1))
    dfcompany = scaler.fit_transform(np.array(dfcompany).reshape(-1,1))
    X_train, X_test, y_train, y_test = split(dfcompany, look_back, percent=0.90)

    h_model = generarHipermodelo(X_train, y_train, X_test, y_test)
    #Entrenamiento del modelo mejorado
    history = h_model.fit(X_train, y_train, epochs=5, batch_size=64, validation_split=0.2, callbacks=[stop_early])

    train_predict, test_predict = prediccion(h_model, X_train, X_test, y_train, y_test, look_back, scaler)

    # Calculamos el error en entrenamiento y test
    train_error = math.sqrt(mean_squared_error(y_train, train_predict))
    test_error = math.sqrt(mean_squared_error(y_test, test_predict))

    print(f"Para la empresa {company}")
    print(f"Error entrenamiento: {train_error}")
    print(f"Error test: {test_error}")

    #graficarResultado(dfcompany, look_back, train_predict, test_predict)
    return (train_error, test_error)

# %%
dictErrores = {}
for company in companies:
    #if company == 'AMZN':
    dfcompany = companies[company]
    dictErrores[company] = generarResultados(dfcompany)
# Out:
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 5s 80ms/step - loss: 0.1548 - mse: 0.1548 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 5.5678e-04 - val_mse: 5.5678e-04
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 4.8990e-04 - val_mse: 4.8990e-04
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 5.6493e-04 - val_mse: 5.6493e-04
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 7.7865e-04 - val_mse: 7.7865e-04
# Para la empresa AAL
# Error entrenamiento: 30.911626933506206
# Error test: 16.366827848965627
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 68ms/step - loss: 0.0427 - mse: 0.0427 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 2/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 1.4516e-04 - val_mse: 1.4516e-04
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 1.5556e-04 - val_mse: 1.5556e-04
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 6.6231e-04 - val_mse: 6.6231e-04
# Para la empresa AAPL
# Error entrenamiento: 198.29751825467324
# Error test: 160.4224155134145
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 118ms/step - loss: 0.0449 - mse: 0.0449 - val_loss: 0.0547 - val_mse: 0.0547
# Epoch 2/5
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 5/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0027 - val_mse: 0.0027
# Para la empresa ADBE
# Error entrenamiento: 376.10239259414783
# Error test: 508.578556096042
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 76ms/step - loss: 0.0248 - mse: 0.0248 - val_loss: 0.0426 - val_mse: 0.0426
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0018 - val_mse: 0.0018
# Para la empresa ADI
# Error entrenamiento: 117.1349554593199
# Error test: 164.310177831009
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 70ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0083 - val_mse: 0.0083
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 3/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0016 - val_mse: 0.0016
# Para la empresa ADP
# Error entrenamiento: 152.10304053176407
# Error test: 208.99649823436908
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 70ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 3/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 5/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0017 - val_mse: 0.0017
# Para la empresa ADSK
# Error entrenamiento: 200.68725433174737
# Error test: 234.57341373841163
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 112ms/step - loss: 0.0673 - mse: 0.0673 - val_loss: 0.0338 - val_mse: 0.0338
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0014 - val_mse: 0.0014
# Para la empresa AKAM
# Error entrenamiento: 86.56531602202334
# Error test: 111.51790806682281
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 12/12 [==============================] - 4s 85ms/step - loss: 0.0462 - mse: 0.0462 - val_loss: 0.0218 - val_mse: 0.0218
# Epoch 2/5
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 3/5
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 4/5
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 5/5
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0028 - val_mse: 0.0028
# Para la empresa ALXN
# Error entrenamiento: 120.45144300243784
# Error test: 173.6457067651963
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 75ms/step - loss: 0.0288 - mse: 0.0288 - val_loss: 0.2071 - val_mse: 0.2071
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.1444 - val_mse: 0.1444
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 9.0437e-04 - mse: 9.0437e-04 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 6.8130e-04 - mse: 6.8130e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Para la empresa AMAT
# Error entrenamiento: 71.28548147753048
# Error test: 135.93596449118598
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 75ms/step - loss: 0.0564 - mse: 0.0564 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0026 - val_mse: 0.0026
# Para la empresa AMGN
# Error entrenamiento: 211.26616313535487
# Error test: 233.46382798304145
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 115ms/step - loss: 0.0400 - mse: 0.0400 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 3/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 9.2658e-04 - val_mse: 9.2658e-04
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 5/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0023 - val_mse: 0.0023
# Para la empresa AMZN
# Error entrenamiento: 2224.327610946917
# Error test: 3023.24878001725
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 72ms/step - loss: 0.0957 - mse: 0.0957 - val_loss: 0.1499 - val_mse: 0.1499
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0353 - val_mse: 0.0353
# Epoch 3/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0044 - val_mse: 0.0044
# Para la empresa ATVI
# Error entrenamiento: 68.37005503810654
# Error test: 75.70774049019978
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 75ms/step - loss: 0.0566 - mse: 0.0566 - val_loss: 0.1249 - val_mse: 0.1249
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0804 - val_mse: 0.0804
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0394 - val_mse: 0.0394
# Epoch 4/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0019 - val_mse: 0.0019
# Para la empresa AVGO
# Error entrenamiento: 334.8565459650972
# Error test: 629.9005142123067
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 80ms/step - loss: 0.0380 - mse: 0.0380 - val_loss: 0.0314 - val_mse: 0.0314
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 5/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0045 - val_mse: 0.0045
# Para la empresa BBBY
# Error entrenamiento: 18.96616731298254
# Error test: 17.571189938569024
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 111ms/step - loss: 0.0453 - mse: 0.0453 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0035 - val_mse: 0.0035
# Para la empresa BIDU
# Error entrenamiento: 187.9069866797932
# Error test: 151.02102707213803
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 69ms/step - loss: 0.1166 - mse: 0.1166 - val_loss: 0.0282 - val_mse: 0.0282
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 5/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0081 - val_mse: 0.0081
# Para la empresa BIIB
# Error entrenamiento: 287.7262220881447
# Error test: 221.0666917287631
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 71ms/step - loss: 0.0359 - mse: 0.0359 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0011 - val_mse: 0.0011
# Para la empresa BMRN
# Error entrenamiento: 86.45365521032963
# Error test: 83.03877065641163
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 115ms/step - loss: 0.0400 - mse: 0.0400 - val_loss: 0.0168 - val_mse: 0.0168
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 9.5792e-04 - val_mse: 9.5792e-04
# Para la empresa CERN
# Error entrenamiento: 68.73573770251163
# Error test: 88.30555999571565
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 71ms/step - loss: 0.0451 - mse: 0.0451 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 4/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 5/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0020 - val_mse: 0.0020
# Para la empresa CHKP
# Error entrenamiento: 112.96380217099643
# Error test: 128.7119182028408
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 71ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0276 - val_mse: 0.0276
# Epoch 2/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 3/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 7.6481e-04 - val_mse: 7.6481e-04
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0018 - val_mse: 0.0018
# Para la empresa CHTR
# Error entrenamiento: 477.09079857611596
# Error test: 575.0555313480414
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 92ms/step - loss: 0.0424 - mse: 0.0424 - val_loss: 0.1011 - val_mse: 0.1011
# Epoch 2/5
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0014 - val_mse: 0.0014
# Para la empresa CMCSA
# Error entrenamiento: 43.097475066038186
# Error test: 47.54928545522254
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 80ms/step - loss: 0.0354 - mse: 0.0354 - val_loss: 0.0745 - val_mse: 0.0745
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 3/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 4/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 7.5808e-04 - val_mse: 7.5808e-04
# Epoch 5/5
# 14/14 [==============================] - 0s 16ms/step - loss: 8.7036e-04 - mse: 8.7036e-04 - val_loss: 4.1362e-04 - val_mse: 4.1362e-04
# Para la empresa COST
# Error entrenamiento: 293.05044616491205
# Error test: 530.0474921402789
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 73ms/step - loss: 0.0527 - mse: 0.0527 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0150 - val_mse: 0.0150
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 5/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 7.0503e-04 - val_mse: 7.0503e-04
# Para la empresa CSCO
# Error entrenamiento: 46.09397996483543
# Error test: 55.66944036962695
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 3s 69ms/step - loss: 0.0479 - mse: 0.0479 - val_loss: 0.0307 - val_mse: 0.0307
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0088 - val_mse: 0.0088
# Para la empresa CSX
# Error entrenamiento: 69.2493627309585
# Error test: 36.35135903339098
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 113ms/step - loss: 0.0573 - mse: 0.0573 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0014 - val_mse: 0.0014
# Para la empresa CTRP
# Error entrenamiento: 37.388189841374874
# Error test: 25.33035813389301
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 76ms/step - loss: 0.1892 - mse: 0.1892 - val_loss: 0.0334 - val_mse: 0.0334
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0254 - mse: 0.0254 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0014 - val_mse: 0.0014
# Para la empresa CTSH
# Error entrenamiento: 69.70915248959092
# Error test: 83.83245786397433
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 70ms/step - loss: 0.0502 - mse: 0.0502 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 5/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0028 - val_mse: 0.0028
# Para la empresa CTXS
# Error entrenamiento: 113.67183692342844
# Error test: 102.41069313774388
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 3s 69ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 3/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 7.7038e-04 - mse: 7.7038e-04 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 6.2222e-04 - mse: 6.2222e-04 - val_loss: 0.0055 - val_mse: 0.0055
# Para la empresa DISCK
# Error entrenamiento: 25.734002200698924
# Error test: 26.169783273502315
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 113ms/step - loss: 0.0536 - mse: 0.0536 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 2/5
# ...
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 6s 223ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 4.0438e-04 - val_mse: 4.0438e-04
# Epoch 3/5
# 14/14 [==============================] - 2s 177ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 6.8854e-04 - val_mse: 6.8854e-04
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 2.2703e-04 - val_mse: 2.2703e-04
# Epoch 5/5
# 14/14 [==============================] - 7s 504ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0025 - val_mse: 0.0025
# Para la empresa TSLA
# Error entrenamiento: 641.0518395131226
# Error test: 1097.9951326872258
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_71"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_71 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 63ms/step - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0320 - val_mse: 0.0320
# Epoch 2/5
# 14/14 [==============================] - 3s 260ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 3/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 4/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 9.7776e-04 - val_mse: 9.7776e-04
# Para la empresa TXN
# Error entrenamiento: 130.9837144404639
# Error test: 176.3886818327873
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_72"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_72 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 61ms/step - loss: 0.0441 - mse: 0.0441 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 2/5
# 14/14 [==============================] - 2s 178ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 3/5
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0031 - val_mse: 0.0031
# Para la empresa ULTA
# Error entrenamiento: 267.01166688470914
# Error test: 365.4194470209294
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_73"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_73 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 6s 229ms/step - loss: 0.0453 - mse: 0.0453 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 6.2486e-04 - val_mse: 6.2486e-04
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 6.0522e-04 - val_mse: 6.0522e-04
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 3.7744e-04 - val_mse: 3.7744e-04
# Para la empresa VOD
# Error entrenamiento: 20.70423956628691
# Error test: 16.87758328667122
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_74"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_74 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 6s 187ms/step - loss: 0.0551 - mse: 0.0551 - val_loss: 0.0348 - val_mse: 0.0348
# Epoch 2/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0119 - val_mse: 0.0119
# Epoch 3/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 5/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0011 - val_mse: 0.0011
# Para la empresa VRSK
# Error entrenamiento: 147.73985226939075
# Error test: 197.15039667323973
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_75"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_75 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_75 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 6s 186ms/step - loss: 0.0882 - mse: 0.0882 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 3/5
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 8.2812e-04 - val_mse: 8.2812e-04
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0041 - mse: 0.0041 - val_loss: 8.3702e-04 - val_mse: 8.3702e-04
# Para la empresa VRTX
# Error entrenamiento: 196.65001239779673
# Error test: 239.60344470018546
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_76"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_76 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 61ms/step - loss: 0.0781 - mse: 0.0781 - val_loss: 0.0261 - val_mse: 0.0261
# Epoch 2/5
# 14/14 [==============================] - 2s 177ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 5/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 9.2454e-04 - val_mse: 9.2454e-04
# Para la empresa WBA
# Error entrenamiento: 58.47576914735828
# Error test: 48.13062465140664
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_77"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_77 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 6s 227ms/step - loss: 0.0650 - mse: 0.0650 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 2/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 4/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 5/5
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0013 - val_mse: 0.0013
# Para la empresa WDC
# Error entrenamiento: 62.21777508645411
# Error test: 52.2541146887276
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_78"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_78 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 13/13 [==============================] - 6s 204ms/step - loss: 0.0271 - mse: 0.0271 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 2/5
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 3/5
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 4/5
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0046 - val_mse: 0.0046
# Epoch 5/5
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0012 - val_mse: 0.0012
# Para la empresa XLNX
# Error entrenamiento: 100.02648617004175
# Error test: 188.16192751284
# INFO:tensorflow:Oracle triggered exit
# Model: "sequential_79"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM1 (LSTM)                 (None, 50, 90)            33120
# _________________________________________________________________
# LSTM2 (LSTM)                 (None, 30)                14520
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_79 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 47,671
# Trainable params: 47,671
# Non-trainable params: 0
# _________________________________________________________________
# 0.01
# Epoch 1/5
# 14/14 [==============================] - 4s 61ms/step - loss: 0.0796 - mse: 0.0796 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 2/5
# 14/14 [==============================] - 3s 260ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 3/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 4/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 5/5
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0048 - val_mse: 0.0048
# Para la empresa XRAY
# Error entrenamiento: 51.062976013359325
# Error test: 50.40137860065438

# %%
for company in dictErrores:
    print (company+ " " + str(dictErrores[company]))
# Out:
# AAL (30.911626933506206, 16.366827848965627)
# AAPL (198.29751825467324, 160.4224155134145)
# ADBE (376.10239259414783, 508.578556096042)
# ADI (117.1349554593199, 164.310177831009)
# ADP (152.10304053176407, 208.99649823436908)
# ADSK (200.68725433174737, 234.57341373841163)
# AKAM (86.56531602202334, 111.51790806682281)
# ALXN (120.45144300243784, 173.6457067651963)
# AMAT (71.28548147753048, 135.93596449118598)
# AMGN (211.26616313535487, 233.46382798304145)
# AMZN (2224.327610946917, 3023.24878001725)
# ATVI (68.37005503810654, 75.70774049019978)
# AVGO (334.8565459650972, 629.9005142123067)
# BBBY (18.96616731298254, 17.571189938569024)
# BIDU (187.9069866797932, 151.02102707213803)
# BIIB (287.7262220881447, 221.0666917287631)
# BMRN (86.45365521032963, 83.03877065641163)
# CERN (68.73573770251163, 88.30555999571565)
# CHKP (112.96380217099643, 128.7119182028408)
# CHTR (477.09079857611596, 575.0555313480414)
# CMCSA (43.097475066038186, 47.54928545522254)
# COST (293.05044616491205, 530.0474921402789)
# CSCO (46.09397996483543, 55.66944036962695)
# CSX (69.2493627309585, 36.35135903339098)
# CTRP (37.388189841374874, 25.33035813389301)
# CTSH (69.70915248959092, 83.83245786397433)
# CTXS (113.67183692342844, 102.41069313774388)
# DISCK (25.734002200698924, 26.169783273502315)
# DISH (37.15234863785317, 31.44137320149903)
# DLTR (95.43614278122543, 134.83725540958937)
# EA (117.7715701037237, 128.09377611115616)
# EXPE (124.84018615951649, 177.68193315966113)
# FAST (48.00737437421078, 55.239407272660074)
# FB (220.73822169588476, 248.75358671388878)
# FISV (102.7224717865759, 99.88027511021441)
# GILD (69.49244545816035, 63.73277116608248)
# GOOGL (1558.0881847914097, 2807.942182096472)
# HSIC (78.51532080259923, 82.59647226041338)
# ILMN (318.45367916472856, 343.70498717721705)
# INCY (85.06599752642886, 73.24272482916712)
# INTC (51.09002954834131, 48.921855346704405)
# INTU (290.89466906354176, 485.0607167256171)
# ISRG (671.277196248987, 304.235999584045)
# JD (54.77400868207092, 69.87055496984078)
# KHC (48.7109772873168, 37.7937655264473)
# LBTYA (26.380196565802763, 26.035936214850054)
# LBTYK (25.563281891144516, 26.13489824149479)
# NTES (270.82876244363996, 109.24926662199248)
# NVDA (329.68434781317535, 244.33196117877975)
# NXPI (130.05789126164902, 195.04880640438284)
# ORLY (388.13078898487777, 620.6872972277191)
# PAYX (79.09624167411555, 119.21833051827805)
# PCAR (73.13622904338818, 87.39542916192957)
# PYPL (150.0156302400403, 130.3543305618996)
# QCOM (94.39129296014416, 171.14766830467553)
# REGN (441.56826254962084, 621.8151553513907)
# ROST (96.27526266332053, 94.71406353524696)
# SBAC (242.2069076956796, 330.7600929599399)
# SBUX (81.23760935859795, 92.61421815101325)
# SIRI (5.469246131611782, 5.5709329194584)
# SRCL (60.7454260677332, 57.36274666788193)
# STX (55.383569610229, 91.26771822560323)
# SWKS (119.39821972646534, 136.74175531629257)
# SYMC (23.21418072987611, 26.38307108549294)
# TMUS (90.97470547984824, 119.22414002470829)
# TRIP (40.64314750769844, 27.219347974152917)
# TSCO (113.50944432351915, 207.28381346814086)
# TSLA (641.0518395131226, 1097.9951326872258)
# TXN (130.9837144404639, 176.3886818327873)
# ULTA (267.01166688470914, 365.4194470209294)
# VOD (20.70423956628691, 16.87758328667122)
# VRSK (147.73985226939075, 197.15039667323973)
# VRTX (196.65001239779673, 239.60344470018546)
# WBA (58.47576914735828, 48.13062465140664)
# WDC (62.21777508645411, 52.2541146887276)
# XLNX (100.02648617004175, 188.16192751284)
# XRAY (51.062976013359325, 50.40137860065438)

# %%
errors = pd.DataFrame(list(dictErrores.values()))
#print(errors)
train_errors = errors[0]
test_errors = errors[1]


print (f"La media del RMSE obtenido en entrenamiento entrenando cada empresa por separado es {np.mean(train_errors)}")
print (f"La media del RMSE obtenido en test entrenando cada empresa por separado es {np.mean(test_errors)}")
# Out:
# La media del RMSE obtenido en entrenamiento entrenando cada empresa por separado es 191.1306885602477
# La media del RMSE obtenido en test entrenando cada empresa por separado es 246.94510698790893

# %%
print(len(train_errors))
# Out:
# 77
